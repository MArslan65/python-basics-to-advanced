# %% [markdown]
# ## lambda function

# %%
add_lambda = lambda x, y: x + y
add_lambda(5, 10)
# Out:
# 15

# %%
number = [600,500,400,300,200,100]
 # lambda function
squaared_number = map(lambda x: x**2, number)
print(list(squaared_number))
# Out:
# [360000, 250000, 160000, 90000, 40000, 10000]
