# %% [markdown]
# # Mutable

# %%
list = ["ali","hamza","rizwan","ali","umer"]

# %%
list[3] = "usman"

# %%
print(list)
# Out:
# ['ali', 'hamza', 'rizwan', 'usman', 'umer']

# %%
tuple = ("ali","hamza","rizwan","ali","umer")
